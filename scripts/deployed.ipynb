# %%
# %reload_ext autoreload
# %autoreload 2
from utils_study_res import study_foto, removing_hits_study
from res_study import main_study

# %%
run_id = "ea7ab94303af439fa9c8a5d364b84a5a"
case_of_study = "train"
is_ensemble = False

# %%
study_foto(run_id, 5)
# Out:
# (71, 128, 62)
# (19, 128, 62)

# %%
main_study(run_id, case_of_study, False, is_ensemble)
# Out:
# Acuracy: 0.8634
# F1 Score: 0.8732
# AUC: 0.8941
# Eficiencia: 0.7422
# Pureza: 0.9299

# %%
removing_hits_study(run_id)
